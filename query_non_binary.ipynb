# %%
import os
import csv
import json
import time
from ollama import chat as ollama_chat

N = 4
models = ["qwen:7b", "mistral", "llama3:latest", "gemma:7b"]

fact_dir = "../data"
json_path = os.path.join(fact_dir, "gold_responses.json")
csv_path = os.path.join(fact_dir, "responses2.csv")

# Lire les substances chimiques depuis le JSON
with open(json_path, "r", encoding="utf-8") as f:
    gold_data = json.load(f)

substances = list(gold_data.keys())[:N]  # Limiter à N substances

def generate_prompt(substance: str) -> str:
    return (
        f"List all diseases related to {substance}. Format your answer strictly as <Disease1, Disease2,...>. "
        f"If no disease is known, answer exactly <None>. Do not include any explanation or extra text."
    )


# Création du CSV de sortie
with open(csv_path, mode="w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["model", "substance_number", "substance", "prompt", "response", "latency_sec"])

    for model_name in models:
        print(f"\n{'='*20} Modèle : {model_name} {'='*20}")
        model_start_time = time.time()

        for i, substance in enumerate(substances):
            prompt = generate_prompt(substance)

            try:
                t0 = time.time()
                response = ollama_chat(model=model_name, messages=[
                    {"role": "user", "content": prompt}
                ])
                latency = time.time() - t0
                answer = response['message']['content'].strip()
            except Exception as e:
                latency = 0.0
                answer = f"ERROR: {e}"

            print(f"[{model_name}] Substance {i+1}")
            print(f"Prompt   : {prompt}")
            print(f"Réponse  : {answer}")
            print(f"Latence  : {latency:.2f} sec")
            print("-" * 50)

            writer.writerow([model_name, i+1, substance, prompt, answer, f"{latency:.2f}"])

        total_time = time.time() - model_start_time
        print(f"\n Temps total pour {model_name} : {total_time:.2f} sec")
        print(f" Réponses écrites dans : {csv_path}")
        print("=" * 60)

print("\n TERMINÉ !")
# Out:
# ==================== Modèle : qwen:7b ====================
# [qwen:7b] Substance 1
# Prompt   : List all diseases related to 06-Paris-LA-66 protocol. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : <None>
# Latence  : 75.93 sec
# --------------------------------------------------
# [qwen:7b] Substance 2
# Prompt   : List all diseases related to 10,10-bis(4-pyridinylmethyl)-9(10H)-anthracenone. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : <None>
# Latence  : 53.98 sec
# --------------------------------------------------
# [qwen:7b] Substance 3
# Prompt   : List all diseases related to 10,11-dihydroxy-N-n-propylnorapomorphine. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : <None>
# Latence  : 33.64 sec
# --------------------------------------------------
# [qwen:7b] Substance 4
# Prompt   : List all diseases related to 10-hydroxycamptothecin. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : <None>
# Latence  : 13.66 sec
# --------------------------------------------------
#
#  Temps total pour qwen:7b : 177.40 sec
#  Réponses écrites dans : ../data/responses2.csv
# ============================================================
#
# ==================== Modèle : mistral ====================
# [mistral] Substance 1
# Prompt   : List all diseases related to 06-Paris-LA-66 protocol. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : Alzheimer's Disease, Parkinson's Disease, Amyotrophic Lateral Sclerosis, Huntington's Disease, Spinocerebellar Ataxia Type 3, Spinal and Bulbar Muscular Atrophy, Multiple System Atrophy, Dementia with Lewy Bodies.
# Latence  : 46.53 sec
# --------------------------------------------------
# [mistral] Substance 2
# Prompt   : List all diseases related to 10,10-bis(4-pyridinylmethyl)-9(10H)-anthracenone. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : None
# Latence  : 13.27 sec
# --------------------------------------------------
# [mistral] Substance 3
# Prompt   : List all diseases related to 10,11-dihydroxy-N-n-propylnorapomorphine. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : 1. Parkinson's Disease
#
# (It's important to note that 10,11-dihydroxy-N-n-propylnorapomorphine is a synthetic analog of apomorphine, which has been used in the treatment of Parkinson's disease.)
#
# In case no direct association with diseases is found: None.
# Latence  : 51.18 sec
# --------------------------------------------------
# [mistral] Substance 4
# Prompt   : List all diseases related to 10-hydroxycamptothecin. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : 10-Hydroxycamptothecin (10-HCPT) is primarily used in research due to its anticancer properties. Therefore, the diseases related to 10-HCPT are predominantly types of cancer that respond to camptothecin derivatives such as:
#
# Camptothecin-resistant Ovarian Cancer, Colorectal Cancer, Lung Cancer, Pancreatic Cancer, Leukemia, Breast Cancer, Glioblastoma Multiforme (Brain Cancer), and Prostate Cancer.
# Latence  : 51.57 sec
# --------------------------------------------------
#
#  Temps total pour mistral : 162.57 sec
#  Réponses écrites dans : ../data/responses2.csv
# ============================================================
#
# ==================== Modèle : llama3:latest ====================
# [llama3:latest] Substance 1
# Prompt   : List all diseases related to 06-Paris-LA-66 protocol. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : Autism Spectrum Disorder, Attention Deficit Hyperactivity Disorder, Anxiety Disorders, Bipolar Disorder, Major Depressive Disorder, Obsessive-Compulsive Disorder
# Latence  : 38.16 sec
# --------------------------------------------------
# [llama3:latest] Substance 2
# Prompt   : List all diseases related to 10,10-bis(4-pyridinylmethyl)-9(10H)-anthracenone. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : <Allergic Reactions, Anaphylaxis, Asthma, Contact Dermatitis>
# Latence  : 16.68 sec
# --------------------------------------------------
# [llama3:latest] Substance 3
# Prompt   : List all diseases related to 10,11-dihydroxy-N-n-propylnorapomorphine. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : <Agitation, Anxiety Disorder, Attention Deficit Hyperactivity Disorder, Bipolar Disorder, Delirium, Depression, Hallucination, Hypomania, Insomnia, Mania, Mood Disorder, Muscle Spasm, Nausea and Vomiting, Neuroleptic Malignant Syndrome, Psychosis, Restlessness, Seizure, Sleep Disorder>
# Latence  : 40.34 sec
# --------------------------------------------------
# [llama3:latest] Substance 4
# Prompt   : List all diseases related to 10-hydroxycamptothecin. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : <Leukemia, Lymphoma, Cervical cancer, Colon cancer, Ovarian cancer, Small cell lung cancer, Breast cancer>
# Latence  : 21.74 sec
# --------------------------------------------------
#
#  Temps total pour llama3:latest : 116.94 sec
#  Réponses écrites dans : ../data/responses2.csv
# ============================================================
#
# ==================== Modèle : gemma:7b ====================
# [gemma:7b] Substance 1
# Prompt   : List all diseases related to 06-Paris-LA-66 protocol. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : None
# Latence  : 80.68 sec
# --------------------------------------------------
# [gemma:7b] Substance 2
# Prompt   : List all diseases related to 10,10-bis(4-pyridinylmethyl)-9(10H)-anthracenone. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : None
# Latence  : 112.70 sec
# --------------------------------------------------
# [gemma:7b] Substance 3
# Prompt   : List all diseases related to 10,11-dihydroxy-N-n-propylnorapomorphine. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : None
# Latence  : 93.18 sec
# --------------------------------------------------
# [gemma:7b] Substance 4
# Prompt   : List all diseases related to 10-hydroxycamptothecin. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : None
# Latence  : 52.49 sec
# --------------------------------------------------
#
#  Temps total pour gemma:7b : 339.37 sec
#  Réponses écrites dans : ../data/responses2.csv
# ============================================================
#
#  TERMINÉ !

# %%
# !ollama list
# Out:
# NAME                 ID              SIZE      MODIFIED
# llama3:latest        365c0bd3c000    4.7 GB    2 minutes ago
# qwen:7b              2091ee8c8d8f    4.5 GB    9 minutes ago
# llama2:latest        78e26419b446    3.8 GB    4 weeks ago
# gemma:2b-instruct    030ee63283b5    1.6 GB    4 weeks ago
# mistral:instruct     f974a74358d6    4.1 GB    4 weeks ago
# llama3:instruct      365c0bd3c000    4.7 GB    4 weeks ago
# mistral:latest       f974a74358d6    4.1 GB    8 weeks ago
# llama3.2:latest      a80c4f17acd5    2.0 GB    2 months ago
# deepseek-r1:1.5b     a42b25d8c10a    1.1 GB    3 months ago

# %%
import os
import csv
import json
import time
from ollama import chat as ollama_chat

N = 4
models = ["qwen:7b", "mistral", "llama3:latest", "gemma:7b"]

fact_dir = "../data"
json_path = os.path.join(fact_dir, "gold_responses.json")
csv_path = os.path.join(fact_dir, "responses2.csv")

# Lire les substances chimiques depuis le JSON
with open(json_path, "r", encoding="utf-8") as f:
    gold_data = json.load(f)

substances = list(gold_data.keys())[:N]  # Limiter à N substances

def generate_prompt(substance: str) -> str:
    return (
        f"List all diseases related to this chemical substance: {substance}. Format your answer strictly as <Disease1, Disease2,...>. "
        f"If no disease is known, answer exactly <None>. Do not include any explanation or extra text."
    )


# Création du CSV de sortie
with open(csv_path, mode="w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["model", "substance_number", "substance", "prompt", "response", "latency_sec"])

    for model_name in models:
        print(f"\n{'='*20} Modèle : {model_name} {'='*20}")
        model_start_time = time.time()

        for i, substance in enumerate(substances):
            prompt = generate_prompt(substance)

            try:
                t0 = time.time()
                response = ollama_chat(model=model_name, messages=[
                    {"role": "user", "content": prompt}
                ])
                latency = time.time() - t0
                answer = response['message']['content'].strip()
            except Exception as e:
                latency = 0.0
                answer = f"ERROR: {e}"

            print(f"[{model_name}] Substance {i+1}")
            print(f"Prompt   : {prompt}")
            print(f"Réponse  : {answer}")
            print(f"Latence  : {latency:.2f} sec")
            print("-" * 50)

            writer.writerow([model_name, i+1, substance, prompt, answer, f"{latency:.2f}"])

        total_time = time.time() - model_start_time
        print(f"\n Temps total pour {model_name} : {total_time:.2f} sec")
        print(f" Réponses écrites dans : {csv_path}")
        print("=" * 60)

print("\n TERMINÉ !")
# Out:
# ==================== Modèle : qwen:7b ====================
# [qwen:7b] Substance 1
# Prompt   : List all diseases related to this chemical substance: 06-Paris-LA-66 protocol. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : <None>
# Latence  : 36.27 sec
# --------------------------------------------------
# [qwen:7b] Substance 2
# Prompt   : List all diseases related to this chemical substance: 10,10-bis(4-pyridinylmethyl)-9(10H)-anthracenone. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : <None>
# Latence  : 11.47 sec
# --------------------------------------------------
# [qwen:7b] Substance 3
# Prompt   : List all diseases related to this chemical substance: 10,11-dihydroxy-N-n-propylnorapomorphine. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : <None>
# Latence  : 8.11 sec
# --------------------------------------------------
# [qwen:7b] Substance 4
# Prompt   : List all diseases related to this chemical substance: 10-hydroxycamptothecin. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : <None>
# Latence  : 21.58 sec
# --------------------------------------------------
#
#  Temps total pour qwen:7b : 77.45 sec
#  Réponses écrites dans : ../data/responses2.csv
# ============================================================
#
# ==================== Modèle : mistral ====================
# [mistral] Substance 1
# Prompt   : List all diseases related to this chemical substance: 06-Paris-LA-66 protocol. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : 06-Paris-LA-66 protocol is a fire retardant used in polyurethane foam and other plastics. As of current scientific knowledge, it's not directly associated with specific diseases.
#
# However, studies have shown potential health effects related to the production, use or disposal of this substance. These include:
#
# - Respiratory issues (e.g., asthma, allergies)
# - Skin irritation and sensitization
# - Eye irritation
# - Potential reproductive toxicity
#
# These health effects are primarily due to the exposure of workers in manufacturing plants or during handling rather than long-term exposure of the general population from everyday products. It's always recommended to consult with a healthcare professional for accurate information on specific medical conditions.
# Latence  : 72.35 sec
# --------------------------------------------------
# [mistral] Substance 2
# Prompt   : List all diseases related to this chemical substance: 10,10-bis(4-pyridinylmethyl)-9(10H)-anthracenone. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : None. As of current scientific knowledge, there are no known diseases directly associated with 10,10-bis(4-pyridinylmethyl)-9(10H)-anthracenone. However, it is always important to remember that substances can have unforeseen effects and ongoing research may reveal new information. Always handle such substances with caution and consult relevant safety guidelines.
# Latence  : 38.26 sec
# --------------------------------------------------
# [mistral] Substance 3
# Prompt   : List all diseases related to this chemical substance: 10,11-dihydroxy-N-n-propylnorapomorphine. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : 10,11-Dihydroxy-N-n-propylnorapomorphine related diseases: Dopamine Dysregulation Syndrome (DDS), Opioid Use Disorder (OUD), Substance Abuse and Dependence.
# Latence  : 41.81 sec
# --------------------------------------------------
# [mistral] Substance 4
# Prompt   : List all diseases related to this chemical substance: 10-hydroxycamptothecin. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : 10-Hydroxycamptothecin is primarily used in research and has not been approved for the treatment of specific human diseases in clinical practice. Therefore, the answer is <None>.
# Latence  : 110.99 sec
# --------------------------------------------------
#
#  Temps total pour mistral : 263.51 sec
#  Réponses écrites dans : ../data/responses2.csv
# ============================================================
#
# ==================== Modèle : llama3:latest ====================
# [llama3:latest] Substance 1
# Prompt   : List all diseases related to this chemical substance: 06-Paris-LA-66 protocol. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : I'm unable to find information on the "06-Paris-LA-66 protocol" chemical substance, so I will provide the default response.
#
# None
# Latence  : 69.69 sec
# --------------------------------------------------
# [llama3:latest] Substance 2
# Prompt   : List all diseases related to this chemical substance: 10,10-bis(4-pyridinylmethyl)-9(10H)-anthracenone. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : <Acute Interstitial Pneumonitis, Autoimmune Hemolytic Anemia, Aplastic Anemia>
# Latence  : 149.40 sec
# --------------------------------------------------
# [llama3:latest] Substance 3
# Prompt   : List all diseases related to this chemical substance: 10,11-dihydroxy-N-n-propylnorapomorphine. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : <Addison's disease, Parkinson's disease>
# Latence  : 37.85 sec
# --------------------------------------------------
# [llama3:latest] Substance 4
# Prompt   : List all diseases related to this chemical substance: 10-hydroxycamptothecin. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : Lymphoma, Breast cancer, Ovarian cancer, Colorectal cancer, Lung cancer, Pancreatic cancer, Cervical cancer, Gastric cancer, Esophageal cancer, Small cell lung cancer, Non-small cell lung cancer, Head and neck cancer, Soft tissue sarcoma
# Latence  : 25.13 sec
# --------------------------------------------------
#
#  Temps total pour llama3:latest : 282.15 sec
#  Réponses écrites dans : ../data/responses2.csv
# ============================================================
#
# ==================== Modèle : gemma:7b ====================
# [gemma:7b] Substance 1
# Prompt   : List all diseases related to this chemical substance: 06-Paris-LA-66 protocol. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : None
# Latence  : 53.04 sec
# --------------------------------------------------
# [gemma:7b] Substance 2
# Prompt   : List all diseases related to this chemical substance: 10,10-bis(4-pyridinylmethyl)-9(10H)-anthracenone. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : None
# Latence  : 48.36 sec
# --------------------------------------------------
# [gemma:7b] Substance 3
# Prompt   : List all diseases related to this chemical substance: 10,11-dihydroxy-N-n-propylnorapomorphine. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : None
# Latence  : 44.17 sec
# --------------------------------------------------
# [gemma:7b] Substance 4
# Prompt   : List all diseases related to this chemical substance: 10-hydroxycamptothecin. Format your answer strictly as <Disease1, Disease2,...>. If no disease is known, answer exactly <None>. Do not include any explanation or extra text.
# Réponse  : None
# Latence  : 59.61 sec
# --------------------------------------------------
#
#  Temps total pour gemma:7b : 205.33 sec
#  Réponses écrites dans : ../data/responses2.csv
# ============================================================
#
#  TERMINÉ !

# %%
import os
import csv
import json
import time
from ollama import chat as ollama_chat

N = 4
models = ["qwen:7b", "mistral", "llama3:latest", "gemma:7b"]

fact_dir = "../data"
json_path = os.path.join(fact_dir, "gold_responses.json")
csv_path = os.path.join(fact_dir, "responses2.csv")

# Lire les substances chimiques depuis le JSON
with open(json_path, "r", encoding="utf-8") as f:
    gold_data = json.load(f)

substances = list(gold_data.keys())[:N]  # Limiter à N substances

def generate_prompt(substance: str) -> str:
    return (
        f"List all diseases related to this chemical substance: {substance}. "
        f"Write one disease name per line, without numbering or formatting. "
        f"If no disease is known, write exactly None. Do not add any explanation or extra text."
    )

# Création du CSV de sortie
with open(csv_path, mode="w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["model", "substance_number", "substance", "prompt", "response", "latency_sec"])

    for model_name in models:
        print(f"\n{'='*20} Modèle : {model_name} {'='*20}")
        model_start_time = time.time()

        for i, substance in enumerate(substances):
            prompt = generate_prompt(substance)

            try:
                t0 = time.time()
                response = ollama_chat(model=model_name, messages=[
                    {"role": "user", "content": prompt}
                ])
                latency = time.time() - t0
                answer = response['message']['content'].strip()
            except Exception as e:
                latency = 0.0
                answer = f"ERROR: {e}"

            print(f"[{model_name}] Substance {i+1}")
            print(f"Prompt   : {prompt}")
            print(f"Réponse  : {answer}")
            print(f"Latence  : {latency:.2f} sec")
            print("-" * 50)

            writer.writerow([model_name, i+1, substance, prompt, answer, f"{latency:.2f}"])

        total_time = time.time() - model_start_time
        print(f"\n Temps total pour {model_name} : {total_time:.2f} sec")
        print(f" Réponses écrites dans : {csv_path}")
        print("=" * 60)

print("\n TERMINÉ !")
# Out:
# ==================== Modèle : qwen:7b ====================
# [qwen:7b] Substance 1
# Prompt   : List all diseases related to this chemical substance: 06-Paris-LA-66 protocol. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : None
# Latence  : 864.97 sec
# --------------------------------------------------
# [qwen:7b] Substance 2
# Prompt   : List all diseases related to this chemical substance: 10,10-bis(4-pyridinylmethyl)-9(10H)-anthracenone. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : None
# Latence  : 22.20 sec
# --------------------------------------------------
# [qwen:7b] Substance 3
# Prompt   : List all diseases related to this chemical substance: 10,11-dihydroxy-N-n-propylnorapomorphine. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : None
# Latence  : 21.20 sec
# --------------------------------------------------
# [qwen:7b] Substance 4
# Prompt   : List all diseases related to this chemical substance: 10-hydroxycamptothecin. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : None
# Latence  : 18.92 sec
# --------------------------------------------------
#
#  Temps total pour qwen:7b : 927.33 sec
#  Réponses écrites dans : ../data/responses2.csv
# ============================================================
#
# ==================== Modèle : mistral ====================
# [mistral] Substance 1
# Prompt   : List all diseases related to this chemical substance: 06-Paris-LA-66 protocol. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : 1. Paris Green Toxicosis
#
# 2. Chronic Beryllium Disease (if Beryllium is a component)
#
# 3. None (if 06-Paris-LA-66 protocol specifically refers to a procedural or manufacturing method and not a chemical substance itself)
# Latence  : 32.50 sec
# --------------------------------------------------
# [mistral] Substance 2
# Prompt   : List all diseases related to this chemical substance: 10,10-bis(4-pyridinylmethyl)-9(10H)-anthracenone. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : 1. Unknown at this time
#
# 2. Unknown at this time
#
# 3. Unknown as of now
#
# 4. Unknown to date
#
# 5. Unknown so far
#
# 6. Unknown yet
#
# 7. None (as of current knowledge)
# Latence  : 37.05 sec
# --------------------------------------------------
# [mistral] Substance 3
# Prompt   : List all diseases related to this chemical substance: 10,11-dihydroxy-N-n-propylnorapomorphine. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : 1. Proaporphine-induced toxicity
#
# 2. Morphinan-related hepatotoxicity
#
# 3. Dopaminergic agonist-associated dyskinesias
#
# 4. Hepatic encephalopathy due to narcotic abuse
#
# 5. Liver cirrhosis from morphine derivatives
#
# 6. Narcotic withdrawal syndrome
#
# 7. Opioid dependence and addiction
#
# 8. Opioid-induced constipation
#
# 9. Respiratory depression related to opioids
#
# 10. Opioid overdose
#
# 11. None (as of current medical knowledge, there is no known disease specifically associated with 10,11-dihydroxy-N-n-propylnorapomorphine that has not been mentioned above)
# Latence  : 262.03 sec
# --------------------------------------------------
# [mistral] Substance 4
# Prompt   : List all diseases related to this chemical substance: 10-hydroxycamptothecin. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : 1. Colorectal Cancer
#
# 2. Ovarian Cancer
#
# 3. Breast Cancer
#
# 4. Lung Cancer
#
# 5. Pancreatic Cancer
#
# 6. Gastric Cancer
#
# 7. Leukemia
#
# 8. Liver Cancer (Hepatocellular Carcinoma)
#
# 9. Esophageal Cancer
#
# 10. Head and Neck Cancers
#
# 11. Prostate Cancer
#
# 12. Uterine Cancer
#
# 13. Glioblastoma Multiforme
#
# 14. Small Cell Lung Cancer
#
# 15. Bladder Cancer
#
# 16. Cervical Cancer
#
# 17. Thyroid Cancer
#
# 18. Sarcoma
#
# 19. Lymphoma
#
# 20. Myeloma
#
# 21. Melanoma
#
# 22. Neuroblastoma
#
# 23. Retinoblastoma
#
# 24. Rhabdomyosarcoma
#
# 25. Glioma
#
# 26. Brainstem Glioma
#
# 27. Malignant Peripheral Nerve Sheath Tumors
#
# 28. Teratocarcinoma
#
# None (if no direct disease association is known)
# Latence  : 75.56 sec
# --------------------------------------------------
#
#  Temps total pour mistral : 407.18 sec
#  Réponses écrites dans : ../data/responses2.csv
# ============================================================
#
# ==================== Modèle : llama3:latest ====================
# [llama3:latest] Substance 1
# Prompt   : List all diseases related to this chemical substance: 06-Paris-LA-66 protocol. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : I'm unable to provide information on the "06-Paris-LA-66 protocol" as it appears to be a fictional or proprietary term. Can you please provide more context or clarify what this refers to? If you meant a different chemical substance, please let me know and I'll do my best to assist you.
#
# If no disease is known related to this substance, the answer would be "None".
# Latence  : 58.66 sec
# --------------------------------------------------
# [llama3:latest] Substance 2
# Prompt   : List all diseases related to this chemical substance: 10,10-bis(4-pyridinylmethyl)-9(10H)-anthracenone. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : None
# Acute myeloid leukemia
# Bladder cancer
# Breast cancer
# Colon cancer
# Lung cancer
# Melanoma
# Ovarian cancer
# Pancreatic cancer
# Prostate cancer
# Latence  : 19.13 sec
# --------------------------------------------------
# [llama3:latest] Substance 3
# Prompt   : List all diseases related to this chemical substance: 10,11-dihydroxy-N-n-propylnorapomorphine. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : Parkinson's disease
# Pain
# Migraine
# Fibromyalgia
# Opioid dependence
# Withdrawal syndrome
# Addiction
# Depression
# Anxiety disorder
# Sleep disorders
# Latence  : 18.96 sec
# --------------------------------------------------
# [llama3:latest] Substance 4
# Prompt   : List all diseases related to this chemical substance: 10-hydroxycamptothecin. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : Small cell lung cancer
# Colorectal cancer
# Ovarian cancer
# Breast cancer
# Pancreatic cancer
# Lymphoma
# Leukemia
# Brain tumor
# Glioblastoma
# Acute myeloid leukemia
# Cervical cancer
# Esophageal cancer
# Stomach cancer
# Latence  : 30.10 sec
# --------------------------------------------------
#
#  Temps total pour llama3:latest : 126.86 sec
#  Réponses écrites dans : ../data/responses2.csv
# ============================================================
#
# ==================== Modèle : gemma:7b ====================
# [gemma:7b] Substance 1
# Prompt   : List all diseases related to this chemical substance: 06-Paris-LA-66 protocol. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : None
# Latence  : 54.45 sec
# --------------------------------------------------
# [gemma:7b] Substance 2
# Prompt   : List all diseases related to this chemical substance: 10,10-bis(4-pyridinylmethyl)-9(10H)-anthracenone. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : None
# Latence  : 1911.49 sec
# --------------------------------------------------
# [gemma:7b] Substance 3
# Prompt   : List all diseases related to this chemical substance: 10,11-dihydroxy-N-n-propylnorapomorphine. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : None
# Latence  : 985.57 sec
# --------------------------------------------------
# [gemma:7b] Substance 4
# Prompt   : List all diseases related to this chemical substance: 10-hydroxycamptothecin. Write one disease name per line, without numbering or formatting. If no disease is known, write exactly None. Do not add any explanation or extra text.
# Réponse  : None
# Latence  : 406.85 sec
# --------------------------------------------------
#
#  Temps total pour gemma:7b : 3358.43 sec
#  Réponses écrites dans : ../data/responses2.csv
# ============================================================
#
#  TERMINÉ !
